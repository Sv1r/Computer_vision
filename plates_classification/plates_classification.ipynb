# %% [markdown]
# <a href="https://www.kaggle.com/maximsviridenko/plates-classification?scriptVersionId=84262563" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Cleaned vs Dirty

# %%
import numpy as np 
import pandas as pd

import os
import zipfile

import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('darkgrid')

import shutil

from tqdm import tqdm

import torch
import torchvision
from torchvision import transforms, models

import time
import copy

# %%
BATCH_SIZE = 8
EPOCHS = 200
IMAGE_SIZE = 224

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Выведем файлы, которы емы имеем в корневой папке проекта - `input`.

# %%
print(os.listdir('../input'))
# Out:
# ['platesv2']

# %% [markdown]
# Распакуем данные из архива в директорию `working`.

# %%
with zipfile.ZipFile('../input/platesv2/plates.zip', 'r') as zip_obj:
   
    zip_obj.extractall('/kaggle/working/')
    
print(os.listdir('/kaggle/working/'))
# Out:
# ['__notebook__.ipynb', '__MACOSX', 'plates']

# %%
data_root = '/kaggle/working/plates/'
print(os.listdir(data_root))
# Out:
# ['test', '.DS_Store', 'train']

# %% [markdown]
# Кажду 6-ю фотографию помести в папку для валидации нашей модели.

# %%
train_dir = 'train'
val_dir = 'val'

class_names = ['cleaned', 'dirty']

for dir_name in [train_dir, val_dir]:
    for class_name in class_names:
        os.makedirs(os.path.join(dir_name, class_name), exist_ok=True)

for class_name in class_names:
    source_dir = os.path.join(data_root, 'train', class_name)
    for i, file_name in enumerate(tqdm(os.listdir(source_dir))):
        if i % 6 != 0:
            dest_dir = os.path.join(train_dir, class_name) 
        else:
            dest_dir = os.path.join(val_dir, class_name)
        shutil.copy(os.path.join(source_dir, file_name), os.path.join(dest_dir, file_name))
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 5659.97it/s]
# 100%|██████████| 21/21 [00:00<00:00, 4923.44it/s]

# %% [markdown]
# Подготовим трансформацию изображений для обеих выборок.

# %%
train_transforms = transforms.Compose([transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
                                       transforms.ColorJitter(hue=(-0.5,0.5)),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.RandomVerticalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Lambda(lambda x: x[np.random.permutation(3), :, :]),
                                       transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

val_transforms = transforms.Compose([transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# %% [markdown]
# Теперь передадим наши трансформации в `ImageFolder`.

# %%
train_dataset = torchvision.datasets.ImageFolder(train_dir, train_transforms)
val_dataset = torchvision.datasets.ImageFolder(val_dir, val_transforms)

# %% [markdown]
# Далее формируем датасеты с размером батча, равным 8-ми.

# %%
train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)

val_dataloader = torch.utils.data.DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %% [markdown]
# Проверим кратность датасетов размеру батча.

# %%
len(train_dataloader), len(train_dataset)
# Out:
# (4, 32)

# %% [markdown]
# Далее визуализируем наши изображения с учетом методов аугментации.

# %%
def show_image_classification(dataloader, title=''):
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    
    try:
        X_batch, y_batch = next(iter(dataloader))
    except:
        X_batch, y_batch, paths = next(iter(test_dataloader))
    
    fig, ax = plt.subplots(2, 3, figsize=(12, 9))

    for x_item, y_item, i, j in zip(X_batch, y_batch, [0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]):
    
        image = x_item.permute(1, 2, 0).numpy()
        image = std * image + mean
        
        title = class_names[y_item]
        
        ax[i, j].imshow(image.clip(0, 1))
        ax[i, j].set_title(title)

        ax[i, j].set_xticks([])
        ax[i, j].set_yticks([])

    fig.tight_layout()
    plt.show()

# %%
show_image_classification(train_dataloader)

# %% [markdown]
# ## Модель

# %% [markdown]
# Определим модель `ResNet18`. В добавок к этому добавим начальные веса.

# %%
model = models.resnet18(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# Обучать мы будем только последний полносвязный слой нашей модели, чтобы сыкономить время обучения.

# %%
for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# Далее переопределим последний полносвязный слой, чтобы совершать градиентный спуст только по нему.

# %%
model.fc = torch.nn.Linear(model.fc.in_features, 2)

# %% [markdown]
# Затем перекладываем модель на `GPU`.

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %% [markdown]
# Определим loss-функцию и метод оптимизации.

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# Определим планировщик, который будет изменять шаг градиентного спуска.

# %%
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %% [markdown]
# ## Обучение

# %% [markdown]
# Обучим модель.

# %%
def train_model(model, loss, optimizer, scheduler, num_epochs):
    
    train_loss_history, valid_loss_history = [], []
    train_accuracy_history, valid_accuracy_history = [], []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}:'.format(epoch, num_epochs - 1), flush=True)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                dataloader = train_dataloader
                model.train()  # Set model to training mode
            else:
                dataloader = val_dataloader
                model.eval()   # Set model to evaluate mode

            running_loss = 0.
            running_acc = 0.

            # Iterate over data.
            for inputs, labels in dataloader:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                # forward and backward
                with torch.set_grad_enabled(phase == 'train'):
                    preds = model(inputs)
                    loss_value = loss(preds, labels)
                    preds_class = preds.argmax(dim=1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss_value.backward()
                        optimizer.step()
                        scheduler.step()

                # statistics
                running_loss += loss_value.item()
                running_acc += (preds_class == labels.data).float().mean()

            epoch_loss = running_loss / len(dataloader)
            epoch_acc = running_acc / len(dataloader)
            
            if phase == 'train':
                train_loss_history.append(epoch_loss)
                train_accuracy_history.append(epoch_acc)
            else:
                valid_loss_history.append(epoch_loss)
                valid_accuracy_history.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc), flush=True)

    return model, train_loss_history, valid_loss_history, train_accuracy_history, valid_accuracy_history

# %%
model, train_loss_history, valid_loss_history, train_accuracy_history, valid_accuracy_history = train_model(
    model, loss, optimizer, scheduler, num_epochs=EPOCHS
);
# Out:
# Epoch 0/199:
# train Loss: 0.9184 Acc: 0.4375
# val Loss: 0.7646 Acc: 0.3750
# Epoch 1/199:
# train Loss: 1.0057 Acc: 0.5625
# val Loss: 1.2236 Acc: 0.5000
# Epoch 2/199:
# train Loss: 0.3774 Acc: 0.8125
# val Loss: 0.9422 Acc: 0.5000
# Epoch 3/199:
# train Loss: 0.4428 Acc: 0.8125
# val Loss: 0.9575 Acc: 0.6250
# Epoch 4/199:
# train Loss: 0.4183 Acc: 0.7812
# val Loss: 0.9532 Acc: 0.6250
# Epoch 5/199:
# train Loss: 0.4309 Acc: 0.7500
# val Loss: 0.9566 Acc: 0.6250
# Epoch 6/199:
# train Loss: 0.4285 Acc: 0.8125
# val Loss: 0.9642 Acc: 0.6250
# Epoch 7/199:
# train Loss: 0.3700 Acc: 0.9062
# val Loss: 0.9693 Acc: 0.6250
# Epoch 8/199:
# train Loss: 0.3491 Acc: 0.8750
# val Loss: 0.9603 Acc: 0.6250
# Epoch 9/199:
# train Loss: 0.4048 Acc: 0.8125
# val Loss: 0.9586 Acc: 0.6250
# Epoch 10/199:
# train Loss: 0.5238 Acc: 0.7500
# val Loss: 0.9674 Acc: 0.6250
# Epoch 11/199:
# train Loss: 0.4555 Acc: 0.8438
# val Loss: 0.9734 Acc: 0.6250
# Epoch 12/199:
# train Loss: 0.4598 Acc: 0.8125
# val Loss: 0.9758 Acc: 0.6250
# Epoch 13/199:
# train Loss: 0.4788 Acc: 0.7812
# val Loss: 1.0046 Acc: 0.6250
# Epoch 14/199:
# train Loss: 0.3950 Acc: 0.8125
# val Loss: 0.9983 Acc: 0.6250
# Epoch 15/199:
# train Loss: 0.4930 Acc: 0.7812
# val Loss: 0.9873 Acc: 0.6250
# Epoch 16/199:
# train Loss: 0.5506 Acc: 0.7188
# val Loss: 0.9905 Acc: 0.6250
# Epoch 17/199:
# train Loss: 0.4322 Acc: 0.7812
# val Loss: 0.9728 Acc: 0.6250
# Epoch 18/199:
# train Loss: 0.4003 Acc: 0.8438
# val Loss: 0.9783 Acc: 0.6250
# Epoch 19/199:
# train Loss: 0.4189 Acc: 0.8438
# val Loss: 0.9817 Acc: 0.6250
# Epoch 20/199:
# train Loss: 0.4639 Acc: 0.8125
# val Loss: 0.9571 Acc: 0.6250
# Epoch 21/199:
# train Loss: 0.4570 Acc: 0.7500
# val Loss: 0.9526 Acc: 0.6250
# Epoch 22/199:
# train Loss: 0.4261 Acc: 0.7812
# val Loss: 0.9500 Acc: 0.6250
# Epoch 23/199:
# train Loss: 0.4311 Acc: 0.8438
# val Loss: 0.9517 Acc: 0.6250
# Epoch 24/199:
# train Loss: 0.4887 Acc: 0.7812
# val Loss: 0.9591 Acc: 0.6250
# Epoch 25/199:
# train Loss: 0.4059 Acc: 0.7812
# val Loss: 0.9521 Acc: 0.6250
# Epoch 26/199:
# train Loss: 0.3625 Acc: 0.8438
# val Loss: 0.9760 Acc: 0.6250
# Epoch 27/199:
# train Loss: 0.4392 Acc: 0.8438
# val Loss: 0.9714 Acc: 0.6250
# Epoch 28/199:
# train Loss: 0.3954 Acc: 0.8750
# val Loss: 0.9719 Acc: 0.6250
# Epoch 29/199:
# train Loss: 0.4146 Acc: 0.7812
# val Loss: 0.9671 Acc: 0.6250
# Epoch 30/199:
# train Loss: 0.4232 Acc: 0.8438
# val Loss: 0.9705 Acc: 0.6250
# Epoch 31/199:
# train Loss: 0.4225 Acc: 0.7812
# val Loss: 0.9705 Acc: 0.6250
# Epoch 32/199:
# train Loss: 0.4301 Acc: 0.7188
# val Loss: 0.9855 Acc: 0.6250
# Epoch 33/199:
# train Loss: 0.4412 Acc: 0.8125
# val Loss: 0.9877 Acc: 0.6250
# Epoch 34/199:
# train Loss: 0.4141 Acc: 0.7812
# val Loss: 0.9844 Acc: 0.6250
# Epoch 35/199:
# train Loss: 0.3529 Acc: 0.9062
# val Loss: 0.9959 Acc: 0.6250
# Epoch 36/199:
# train Loss: 0.3718 Acc: 0.7812
# val Loss: 1.0163 Acc: 0.6250
# Epoch 37/199:
# train Loss: 0.4527 Acc: 0.7500
# val Loss: 1.0062 Acc: 0.6250
# Epoch 38/199:
# train Loss: 0.3357 Acc: 0.8750
# val Loss: 1.0010 Acc: 0.6250
# Epoch 39/199:
# train Loss: 0.4268 Acc: 0.7812
# val Loss: 0.9775 Acc: 0.6250
# Epoch 40/199:
# train Loss: 0.4319 Acc: 0.7812
# val Loss: 0.9652 Acc: 0.6250
# Epoch 41/199:
# train Loss: 0.5775 Acc: 0.7812
# val Loss: 0.9672 Acc: 0.6250
# Epoch 42/199:
# train Loss: 0.3834 Acc: 0.9062
# val Loss: 0.9713 Acc: 0.6250
# Epoch 43/199:
# train Loss: 0.4280 Acc: 0.8438
# val Loss: 0.9889 Acc: 0.6250
# Epoch 44/199:
# train Loss: 0.4318 Acc: 0.7500
# val Loss: 0.9878 Acc: 0.6250
# Epoch 45/199:
# train Loss: 0.4862 Acc: 0.7812
# val Loss: 0.9879 Acc: 0.6250
# Epoch 46/199:
# train Loss: 0.4277 Acc: 0.8438
# val Loss: 0.9887 Acc: 0.6250
# Epoch 47/199:
# train Loss: 0.5170 Acc: 0.8125
# val Loss: 0.9861 Acc: 0.6250
# Epoch 48/199:
# train Loss: 0.4566 Acc: 0.7188
# val Loss: 0.9972 Acc: 0.6250
# Epoch 49/199:
# train Loss: 0.4715 Acc: 0.7500
# val Loss: 0.9945 Acc: 0.6250
# Epoch 50/199:
# train Loss: 0.4198 Acc: 0.8125
# val Loss: 0.9927 Acc: 0.6250
# Epoch 51/199:
# train Loss: 0.4071 Acc: 0.8125
# val Loss: 0.9801 Acc: 0.6250
# Epoch 52/199:
# train Loss: 0.4487 Acc: 0.7812
# val Loss: 0.9796 Acc: 0.6250
# Epoch 53/199:
# train Loss: 0.4108 Acc: 0.8125
# val Loss: 0.9686 Acc: 0.6250
# Epoch 54/199:
# train Loss: 0.5937 Acc: 0.6875
# val Loss: 0.9572 Acc: 0.6250
# Epoch 55/199:
# train Loss: 0.3728 Acc: 0.8125
# val Loss: 0.9622 Acc: 0.6250
# Epoch 56/199:
# train Loss: 0.4845 Acc: 0.8438
# val Loss: 0.9800 Acc: 0.6250
# Epoch 57/199:
# train Loss: 0.3763 Acc: 0.8438
# val Loss: 0.9724 Acc: 0.6250
# Epoch 58/199:
# train Loss: 0.3986 Acc: 0.8438
# val Loss: 0.9600 Acc: 0.6250
# Epoch 59/199:
# train Loss: 0.4015 Acc: 0.8438
# val Loss: 0.9878 Acc: 0.6250
# Epoch 60/199:
# train Loss: 0.4166 Acc: 0.7500
# val Loss: 0.9945 Acc: 0.6250
# Epoch 61/199:
# train Loss: 0.4315 Acc: 0.8438
# val Loss: 0.9930 Acc: 0.6250
# Epoch 62/199:
# train Loss: 0.4243 Acc: 0.7812
# val Loss: 1.0059 Acc: 0.6250
# Epoch 63/199:
# train Loss: 0.3933 Acc: 0.8438
# val Loss: 0.9828 Acc: 0.6250
# Epoch 64/199:
# train Loss: 0.4092 Acc: 0.8438
# val Loss: 0.9817 Acc: 0.6250
# Epoch 65/199:
# train Loss: 0.3874 Acc: 0.8125
# val Loss: 0.9876 Acc: 0.6250
# Epoch 66/199:
# train Loss: 0.4792 Acc: 0.7812
# val Loss: 0.9878 Acc: 0.6250
# Epoch 67/199:
# train Loss: 0.4825 Acc: 0.8125
# val Loss: 0.9953 Acc: 0.6250
# Epoch 68/199:
# train Loss: 0.5087 Acc: 0.7500
# val Loss: 0.9816 Acc: 0.6250
# Epoch 69/199:
# train Loss: 0.3375 Acc: 0.8438
# val Loss: 0.9670 Acc: 0.6250
# Epoch 70/199:
# train Loss: 0.3868 Acc: 0.8750
# val Loss: 0.9719 Acc: 0.6250
# Epoch 71/199:
# train Loss: 0.4478 Acc: 0.8125
# val Loss: 0.9840 Acc: 0.6250
# Epoch 72/199:
# train Loss: 0.3975 Acc: 0.8438
# val Loss: 0.9799 Acc: 0.6250
# Epoch 73/199:
# train Loss: 0.3863 Acc: 0.8750
# val Loss: 0.9985 Acc: 0.6250
# Epoch 74/199:
# train Loss: 0.4049 Acc: 0.8125
# val Loss: 0.9967 Acc: 0.6250
# Epoch 75/199:
# train Loss: 0.3979 Acc: 0.7812
# val Loss: 1.0061 Acc: 0.6250
# Epoch 76/199:
# train Loss: 0.3729 Acc: 0.8125
# val Loss: 0.9957 Acc: 0.6250
# Epoch 77/199:
# train Loss: 0.5000 Acc: 0.7812
# val Loss: 0.9558 Acc: 0.6250
# Epoch 78/199:
# train Loss: 0.4202 Acc: 0.7188
# val Loss: 0.9600 Acc: 0.6250
# Epoch 79/199:
# train Loss: 0.3907 Acc: 0.8750
# val Loss: 0.9637 Acc: 0.6250
# Epoch 80/199:
# train Loss: 0.3709 Acc: 0.8125
# val Loss: 0.9555 Acc: 0.6250
# Epoch 81/199:
# train Loss: 0.4511 Acc: 0.8125
# val Loss: 0.9408 Acc: 0.6250
# Epoch 82/199:
# train Loss: 0.4169 Acc: 0.7812
# val Loss: 0.9475 Acc: 0.6250
# Epoch 83/199:
# train Loss: 0.3900 Acc: 0.8125
# val Loss: 0.9473 Acc: 0.6250
# Epoch 84/199:
# train Loss: 0.4944 Acc: 0.7188
# val Loss: 0.9708 Acc: 0.6250
# Epoch 85/199:
# train Loss: 0.5022 Acc: 0.6875
# val Loss: 0.9778 Acc: 0.6250
# Epoch 86/199:
# train Loss: 0.5408 Acc: 0.7812
# val Loss: 0.9888 Acc: 0.6250
# Epoch 87/199:
# train Loss: 0.5674 Acc: 0.6562
# val Loss: 0.9817 Acc: 0.6250
# Epoch 88/199:
# train Loss: 0.3559 Acc: 0.8438
# val Loss: 0.9866 Acc: 0.6250
# Epoch 89/199:
# train Loss: 0.3561 Acc: 0.8125
# val Loss: 0.9915 Acc: 0.6250
# Epoch 90/199:
# train Loss: 0.4141 Acc: 0.8125
# val Loss: 0.9794 Acc: 0.6250
# Epoch 91/199:
# train Loss: 0.5743 Acc: 0.6562
# val Loss: 0.9902 Acc: 0.6250
# Epoch 92/199:
# train Loss: 0.4702 Acc: 0.8125
# val Loss: 0.9947 Acc: 0.6250
# Epoch 93/199:
# train Loss: 0.5371 Acc: 0.7188
# val Loss: 0.9913 Acc: 0.6250
# Epoch 94/199:
# train Loss: 0.4047 Acc: 0.8125
# val Loss: 0.9834 Acc: 0.6250
# Epoch 95/199:
# train Loss: 0.4397 Acc: 0.7812
# val Loss: 0.9942 Acc: 0.6250
# Epoch 96/199:
# train Loss: 0.4879 Acc: 0.8438
# val Loss: 0.9918 Acc: 0.6250
# Epoch 97/199:
# train Loss: 0.3669 Acc: 0.8125
# val Loss: 0.9902 Acc: 0.6250
# Epoch 98/199:
# train Loss: 0.4722 Acc: 0.8125
# val Loss: 1.0027 Acc: 0.6250
# Epoch 99/199:
# train Loss: 0.3786 Acc: 0.8125
# val Loss: 0.9986 Acc: 0.6250
# Epoch 100/199:
# train Loss: 0.3243 Acc: 0.9062
# val Loss: 0.9904 Acc: 0.6250
# Epoch 101/199:
# train Loss: 0.4097 Acc: 0.7812
# val Loss: 0.9530 Acc: 0.6250
# Epoch 102/199:
# train Loss: 0.3409 Acc: 0.8438
# val Loss: 0.9646 Acc: 0.6250
# Epoch 103/199:
# train Loss: 0.3959 Acc: 0.8438
# val Loss: 0.9812 Acc: 0.6250
# Epoch 104/199:
# train Loss: 0.4268 Acc: 0.7812
# val Loss: 0.9829 Acc: 0.6250
# Epoch 105/199:
# train Loss: 0.4190 Acc: 0.8125
# val Loss: 0.9789 Acc: 0.6250
# Epoch 106/199:
# train Loss: 0.5231 Acc: 0.7188
# val Loss: 0.9799 Acc: 0.6250
# Epoch 107/199:
# train Loss: 0.3721 Acc: 0.7812
# val Loss: 0.9813 Acc: 0.6250
# Epoch 108/199:
# train Loss: 0.4163 Acc: 0.8125
# val Loss: 0.9684 Acc: 0.6250
# Epoch 109/199:
# train Loss: 0.4152 Acc: 0.8438
# val Loss: 0.9728 Acc: 0.6250
# Epoch 110/199:
# train Loss: 0.4060 Acc: 0.8438
# val Loss: 0.9571 Acc: 0.6250
# Epoch 111/199:
# train Loss: 0.4679 Acc: 0.7188
# val Loss: 0.9724 Acc: 0.6250
# Epoch 112/199:
# train Loss: 0.4006 Acc: 0.8438
# val Loss: 0.9885 Acc: 0.6250
# Epoch 113/199:
# train Loss: 0.6034 Acc: 0.7500
# val Loss: 0.9912 Acc: 0.6250
# Epoch 114/199:
# train Loss: 0.5158 Acc: 0.6875
# val Loss: 1.0026 Acc: 0.6250
# Epoch 115/199:
# train Loss: 0.3887 Acc: 0.8750
# val Loss: 0.9951 Acc: 0.6250
# Epoch 116/199:
# train Loss: 0.3565 Acc: 0.8438
# val Loss: 0.9895 Acc: 0.6250
# Epoch 117/199:
# train Loss: 0.4127 Acc: 0.7812
# val Loss: 0.9904 Acc: 0.6250
# Epoch 118/199:
# train Loss: 0.4032 Acc: 0.8125
# val Loss: 0.9966 Acc: 0.6250
# Epoch 119/199:
# train Loss: 0.5396 Acc: 0.7500
# val Loss: 0.9971 Acc: 0.6250
# Epoch 120/199:
# train Loss: 0.4052 Acc: 0.7188
# val Loss: 0.9893 Acc: 0.6250
# Epoch 121/199:
# train Loss: 0.4897 Acc: 0.8438
# val Loss: 0.9909 Acc: 0.6250
# Epoch 122/199:
# train Loss: 0.5719 Acc: 0.6562
# val Loss: 0.9939 Acc: 0.6250
# Epoch 123/199:
# train Loss: 0.3430 Acc: 0.8125
# val Loss: 1.0060 Acc: 0.6250
# Epoch 124/199:
# train Loss: 0.5457 Acc: 0.8125
# val Loss: 0.9889 Acc: 0.6250
# Epoch 125/199:
# train Loss: 0.5525 Acc: 0.6562
# val Loss: 0.9821 Acc: 0.6250
# Epoch 126/199:
# train Loss: 0.3972 Acc: 0.8438
# val Loss: 0.9922 Acc: 0.6250
# Epoch 127/199:
# train Loss: 0.5070 Acc: 0.7188
# val Loss: 0.9842 Acc: 0.6250
# Epoch 128/199:
# train Loss: 0.3951 Acc: 0.8125
# val Loss: 0.9961 Acc: 0.6250
# Epoch 129/199:
# train Loss: 0.4564 Acc: 0.7812
# val Loss: 0.9719 Acc: 0.6250
# Epoch 130/199:
# train Loss: 0.3246 Acc: 0.8438
# val Loss: 0.9720 Acc: 0.6250
# Epoch 131/199:
# train Loss: 0.5194 Acc: 0.7500
# val Loss: 0.9626 Acc: 0.6250
# Epoch 132/199:
# train Loss: 0.4789 Acc: 0.7812
# val Loss: 0.9598 Acc: 0.6250
# Epoch 133/199:
# train Loss: 0.5316 Acc: 0.6875
# val Loss: 0.9436 Acc: 0.6250
# Epoch 134/199:
# train Loss: 0.4472 Acc: 0.7812
# val Loss: 0.9609 Acc: 0.6250
# Epoch 135/199:
# train Loss: 0.3571 Acc: 0.8750
# val Loss: 0.9641 Acc: 0.6250
# Epoch 136/199:
# train Loss: 0.4818 Acc: 0.7500
# val Loss: 0.9445 Acc: 0.6250
# Epoch 137/199:
# train Loss: 0.3718 Acc: 0.8125
# val Loss: 0.9318 Acc: 0.6250
# Epoch 138/199:
# train Loss: 0.4628 Acc: 0.7500
# val Loss: 0.9422 Acc: 0.6250
# Epoch 139/199:
# train Loss: 0.4472 Acc: 0.7812
# val Loss: 0.9467 Acc: 0.6250
# Epoch 140/199:
# train Loss: 0.4260 Acc: 0.7500
# val Loss: 0.9519 Acc: 0.6250
# Epoch 141/199:
# train Loss: 0.3666 Acc: 0.9062
# val Loss: 0.9690 Acc: 0.6250
# Epoch 142/199:
# train Loss: 0.3622 Acc: 0.8438
# val Loss: 0.9641 Acc: 0.6250
# Epoch 143/199:
# train Loss: 0.3523 Acc: 0.8750
# val Loss: 0.9775 Acc: 0.6250
# Epoch 144/199:
# train Loss: 0.4203 Acc: 0.7812
# val Loss: 0.9700 Acc: 0.6250
# Epoch 145/199:
# train Loss: 0.3668 Acc: 0.9062
# val Loss: 0.9965 Acc: 0.6250
# Epoch 146/199:
# train Loss: 0.4914 Acc: 0.7188
# val Loss: 0.9972 Acc: 0.6250
# Epoch 147/199:
# train Loss: 0.4056 Acc: 0.8750
# val Loss: 0.9978 Acc: 0.6250
# Epoch 148/199:
# train Loss: 0.4115 Acc: 0.8438
# val Loss: 0.9831 Acc: 0.6250
# Epoch 149/199:
# train Loss: 0.3923 Acc: 0.7812
# val Loss: 0.9838 Acc: 0.6250
# Epoch 150/199:
# train Loss: 0.4634 Acc: 0.7188
# val Loss: 0.9773 Acc: 0.6250
# Epoch 151/199:
# train Loss: 0.3722 Acc: 0.8750
# val Loss: 0.9798 Acc: 0.6250
# Epoch 152/199:
# train Loss: 0.3790 Acc: 0.8438
# val Loss: 0.9680 Acc: 0.6250
# Epoch 153/199:
# train Loss: 0.4813 Acc: 0.8438
# val Loss: 0.9828 Acc: 0.6250
# Epoch 154/199:
# train Loss: 0.3931 Acc: 0.7500
# val Loss: 0.9613 Acc: 0.6250
# Epoch 155/199:
# train Loss: 0.4264 Acc: 0.8125
# val Loss: 0.9714 Acc: 0.6250
# Epoch 156/199:
# train Loss: 0.3626 Acc: 0.7812
# val Loss: 0.9719 Acc: 0.6250
# Epoch 157/199:
# train Loss: 0.4533 Acc: 0.7812
# val Loss: 0.9646 Acc: 0.6250
# Epoch 158/199:
# train Loss: 0.4929 Acc: 0.7500
# val Loss: 0.9754 Acc: 0.6250
# Epoch 159/199:
# train Loss: 0.3903 Acc: 0.8125
# val Loss: 0.9915 Acc: 0.6250
# Epoch 160/199:
# train Loss: 0.3704 Acc: 0.8750
# val Loss: 0.9785 Acc: 0.6250
# Epoch 161/199:
# train Loss: 0.4779 Acc: 0.7812
# val Loss: 0.9481 Acc: 0.6250
# Epoch 162/199:
# train Loss: 0.4420 Acc: 0.7812
# val Loss: 0.9650 Acc: 0.6250
# Epoch 163/199:
# train Loss: 0.4319 Acc: 0.7500
# val Loss: 0.9663 Acc: 0.6250
# Epoch 164/199:
# train Loss: 0.4816 Acc: 0.8125
# val Loss: 0.9687 Acc: 0.6250
# Epoch 165/199:
# train Loss: 0.3977 Acc: 0.8438
# val Loss: 0.9721 Acc: 0.6250
# Epoch 166/199:
# train Loss: 0.5460 Acc: 0.7188
# val Loss: 0.9752 Acc: 0.6250
# Epoch 167/199:
# train Loss: 0.4334 Acc: 0.7812
# val Loss: 0.9709 Acc: 0.6250
# Epoch 168/199:
# train Loss: 0.4206 Acc: 0.7812
# val Loss: 0.9727 Acc: 0.6250
# Epoch 169/199:
# train Loss: 0.4386 Acc: 0.8125
# val Loss: 0.9504 Acc: 0.6250
# Epoch 170/199:
# train Loss: 0.4603 Acc: 0.7812
# val Loss: 0.9526 Acc: 0.6250
# Epoch 171/199:
# train Loss: 0.5303 Acc: 0.7812
# val Loss: 0.9608 Acc: 0.6250
# Epoch 172/199:
# train Loss: 0.4284 Acc: 0.8125
# val Loss: 0.9432 Acc: 0.6250
# Epoch 173/199:
# train Loss: 0.4328 Acc: 0.7812
# val Loss: 0.9664 Acc: 0.6250
# Epoch 174/199:
# train Loss: 0.3395 Acc: 0.8438
# val Loss: 0.9686 Acc: 0.6250
# Epoch 175/199:
# train Loss: 0.4338 Acc: 0.8125
# val Loss: 0.9600 Acc: 0.6250
# Epoch 176/199:
# train Loss: 0.3812 Acc: 0.8438
# val Loss: 0.9787 Acc: 0.6250
# Epoch 177/199:
# train Loss: 0.4102 Acc: 0.8750
# val Loss: 0.9644 Acc: 0.6250
# Epoch 178/199:
# train Loss: 0.4409 Acc: 0.8438
# val Loss: 0.9661 Acc: 0.6250
# Epoch 179/199:
# train Loss: 0.3801 Acc: 0.7812
# val Loss: 0.9607 Acc: 0.6250
# Epoch 180/199:
# train Loss: 0.4210 Acc: 0.8125
# val Loss: 0.9715 Acc: 0.6250
# Epoch 181/199:
# train Loss: 0.3636 Acc: 0.7812
# val Loss: 0.9657 Acc: 0.6250
# Epoch 182/199:
# train Loss: 0.3336 Acc: 0.8438
# val Loss: 0.9678 Acc: 0.6250
# Epoch 183/199:
# train Loss: 0.4047 Acc: 0.8125
# val Loss: 0.9607 Acc: 0.6250
# Epoch 184/199:
# train Loss: 0.5117 Acc: 0.7188
# val Loss: 0.9670 Acc: 0.6250
# Epoch 185/199:
# train Loss: 0.4697 Acc: 0.7500
# val Loss: 0.9479 Acc: 0.6250
# Epoch 186/199:
# train Loss: 0.3605 Acc: 0.8438
# val Loss: 0.9408 Acc: 0.6250
# Epoch 187/199:
# train Loss: 0.3811 Acc: 0.8438
# val Loss: 0.9404 Acc: 0.6250
# Epoch 188/199:
# train Loss: 0.3393 Acc: 0.8125
# val Loss: 0.9589 Acc: 0.6250
# Epoch 189/199:
# train Loss: 0.4208 Acc: 0.8438
# val Loss: 0.9721 Acc: 0.6250
# Epoch 190/199:
# train Loss: 0.3659 Acc: 0.8438
# val Loss: 0.9650 Acc: 0.6250
# Epoch 191/199:
# train Loss: 0.4788 Acc: 0.8125
# val Loss: 0.9788 Acc: 0.6250
# Epoch 192/199:
# train Loss: 0.4344 Acc: 0.7500
# val Loss: 0.9986 Acc: 0.6250
# Epoch 193/199:
# train Loss: 0.3324 Acc: 0.8438
# val Loss: 0.9958 Acc: 0.6250
# Epoch 194/199:
# train Loss: 0.3778 Acc: 0.8438
# val Loss: 0.9784 Acc: 0.6250
# Epoch 195/199:
# train Loss: 0.4235 Acc: 0.6875
# val Loss: 0.9650 Acc: 0.6250
# Epoch 196/199:
# train Loss: 0.4618 Acc: 0.7812
# val Loss: 0.9768 Acc: 0.6250
# Epoch 197/199:
# train Loss: 0.4600 Acc: 0.8125
# val Loss: 0.9832 Acc: 0.6250
# Epoch 198/199:
# train Loss: 0.4109 Acc: 0.8125
# val Loss: 0.9739 Acc: 0.6250
# Epoch 199/199:
# train Loss: 0.4156 Acc: 0.8125
# val Loss: 0.9626 Acc: 0.6250

# %%
dict_data  = {
    'Loss Function Train' : train_loss_history,
    'Loss Function Valid' : valid_loss_history,
    'Accuracy Train' : train_accuracy_history,
    'Accuracy Valid' : valid_accuracy_history
}

# %%
df_results = pd.DataFrame.from_dict(dict_data)

# %%
def loss_plot(data):
    
    loss_names = data.columns[:2]
    accuracy_names = data.columns[2:]
    legend_names = ['Train', 'Valid']
    
    fig, ax = plt.subplots(1, 2, figsize=(20, 8))
    
    for i, j, k in zip(loss_names, accuracy_names, legend_names):
        
        ax[0].plot(data[i].values, label=k)
        ax[1].plot(data[j].values, label=k)
        
    for i, j in enumerate(['Loss', 'Accuracy']):

        ax[i].set_title(f'{j} Loss Plot', fontsize=14)
        ax[i].set_xlabel('Epoch', fontsize=12)
        ax[i].set_ylabel(f'{j} Loss Function Value', fontsize=12)
        ax[i].legend()
        
    fig.suptitle('Result of Model Training', fontsize=18)
    plt.show()

# %% [markdown]
# Посмотрим, как изменялся loss и accuracy нашей модели.

# %%
loss_plot(df_results)

# %% [markdown]
# ## Предсказание модели

# %%
test_dir = 'test'
shutil.copytree(os.path.join(data_root, 'test'), os.path.join(test_dir, 'unknown'))
# Out:
# 'test/unknown'

# %%
class ImageFolderWithPaths(torchvision.datasets.ImageFolder):
    def __getitem__(self, index):
        original_tuple = super(ImageFolderWithPaths, self).__getitem__(index)
        path = self.imgs[index][0]
        tuple_with_path = (original_tuple + (path,))
        return tuple_with_path
    
test_dataset = ImageFolderWithPaths('/kaggle/working/test', val_transforms)

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

# %%
test_dataset
# Out:
# Dataset ImageFolderWithPaths
#     Number of datapoints: 744
#     Root location: /kaggle/working/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# Делаем предсказание.

# %%
model.eval()

test_predictions = []
test_img_paths = []
for inputs, labels, paths in tqdm(test_dataloader):
    inputs = inputs.to(device)
    labels = labels.to(device)
    with torch.set_grad_enabled(False):
        preds = model(inputs)
    test_predictions.append(
        torch.nn.functional.softmax(preds, dim=1)[:,1].data.cpu().numpy())
    test_img_paths.extend(paths)
    
test_predictions = np.concatenate(test_predictions)
# Out:
# 100%|██████████| 93/93 [00:03<00:00, 27.54it/s]

# %% [markdown]
# Далее создадим `.csv` наших предсказаний.

# %%
submission_df = pd.DataFrame.from_dict({'id': test_img_paths, 'label': test_predictions})

submission_df['label'] = submission_df['label'].map(lambda pred: 'dirty' if pred > 0.25 else 'cleaned')
submission_df['id'] = submission_df['id'].str.replace('/kaggle/working/test/unknown/', '')
submission_df['id'] = submission_df['id'].str.replace('.jpg', '')
submission_df.set_index('id', inplace=True)
submission_df.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
#       label
# id
# 0000  dirty
# 0001  dirty
# 0002  dirty
# 0003  dirty
# 0004  dirty

# %% [markdown]
# Скачиваем файлы.

# %%
submission_df.to_csv('submission.csv')

from IPython.display import FileLink
FileLink('submission.csv')
# Out:
# /kaggle/working/submission.csv

# %% [markdown]
# Очищаем рабочую папку.

# %%
# !rm -rf train val test
