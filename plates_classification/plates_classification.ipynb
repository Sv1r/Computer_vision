# %% [markdown]
# <a href="https://www.kaggle.com/maximsviridenko/plates-classification?scriptVersionId=84259311" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Cleaned vs Dirty

# %%
import numpy as np 
import pandas as pd

import os
import zipfile

import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('darkgrid')

import shutil

from tqdm import tqdm

import torch
import torchvision
from torchvision import transforms, models

import time
import copy

# %%
BATCH_SIZE = 8
EPOCHS = 200
IMAGE_SIZE = 224

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Выведем файлы, которы емы имеем в корневой папке проекта - `input`.

# %%
print(os.listdir('../input'))
# Out:
# ['platesv2']

# %% [markdown]
# Распакуем данные из архива в директорию `working`.

# %%
with zipfile.ZipFile('../input/platesv2/plates.zip', 'r') as zip_obj:
   
    zip_obj.extractall('/kaggle/working/')
    
print(os.listdir('/kaggle/working/'))
# Out:
# ['__notebook__.ipynb', '__MACOSX', 'plates']

# %%
data_root = '/kaggle/working/plates/'
print(os.listdir(data_root))
# Out:
# ['.DS_Store', 'test', 'train']

# %% [markdown]
# Кажду 6-ю фотографию помести в папку для валидации нашей модели.

# %%
train_dir = 'train'
val_dir = 'val'

class_names = ['cleaned', 'dirty']

for dir_name in [train_dir, val_dir]:
    for class_name in class_names:
        os.makedirs(os.path.join(dir_name, class_name), exist_ok=True)

for class_name in class_names:
    source_dir = os.path.join(data_root, 'train', class_name)
    for i, file_name in enumerate(tqdm(os.listdir(source_dir))):
        if i % 6 != 0:
            dest_dir = os.path.join(train_dir, class_name) 
        else:
            dest_dir = os.path.join(val_dir, class_name)
        shutil.copy(os.path.join(source_dir, file_name), os.path.join(dest_dir, file_name))
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 5735.15it/s]
# 100%|██████████| 21/21 [00:00<00:00, 5390.15it/s]

# %% [markdown]
# Подготовим трансформацию изображений для обеих выборок.

# %%
train_transforms = transforms.Compose([transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
                                       transforms.ColorJitter(hue=(-0.5,0.5)),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.RandomVerticalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Lambda(lambda x: x[np.random.permutation(3), :, :]),
                                       transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

val_transforms = transforms.Compose([transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# %% [markdown]
# Теперь передадим наши трансформации в `ImageFolder`.

# %%
train_dataset = torchvision.datasets.ImageFolder(train_dir, train_transforms)
val_dataset = torchvision.datasets.ImageFolder(val_dir, val_transforms)

# %% [markdown]
# Далее формируем датасеты с размером батча, равным 8-ми.

# %%
train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)

val_dataloader = torch.utils.data.DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %% [markdown]
# Проверим кратность датасетов размеру батча.

# %%
len(train_dataloader), len(train_dataset)
# Out:
# (4, 32)

# %% [markdown]
# Далее визуализируем наши изображения с учетом методов аугментации.

# %%
def show_image_classification(dataloader, title=''):
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    
    try:
        X_batch, y_batch = next(iter(dataloader))
    except:
        X_batch, y_batch, paths = next(iter(test_dataloader))
    
    fig, ax = plt.subplots(2, 3, figsize=(12, 9))

    for x_item, y_item, i, j in zip(X_batch, y_batch, [0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]):
    
        image = x_item.permute(1, 2, 0).numpy()
        image = std * image + mean
        
        title = class_names[y_item]
        
        ax[i, j].imshow(image.clip(0, 1))
        ax[i, j].set_title(title)

        ax[i, j].set_xticks([])
        ax[i, j].set_yticks([])

    fig.tight_layout()
    plt.show()

# %%
show_image_classification(train_dataloader)

# %% [markdown]
# ## Модель

# %% [markdown]
# Определим модель `ResNet18`. В добавок к этому добавим начальные веса.

# %%
model = models.resnet18(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# Обучать мы будем только последний полносвязный слой нашей модели, чтобы сыкономить время обучения.

# %%
for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# Далее переопределим последний полносвязный слой, чтобы совершать градиентный спуст только по нему.

# %%
model.fc = torch.nn.Linear(model.fc.in_features, 2)

# %% [markdown]
# Затем перекладываем модель на `GPU`.

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %% [markdown]
# Определим loss-функцию и метод оптимизации.

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# Определим планировщик, который будет изменять шаг градиентного спуска.

# %%
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %% [markdown]
# ## Обучение

# %% [markdown]
# Обучим модель.

# %%
def train_model(model, loss, optimizer, scheduler, num_epochs):
    
    train_loss_history, valid_loss_history = [], []
    train_accuracy_history, valid_accuracy_history = [], []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}:'.format(epoch, num_epochs - 1), flush=True)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                dataloader = train_dataloader
                model.train()  # Set model to training mode
            else:
                dataloader = val_dataloader
                model.eval()   # Set model to evaluate mode

            running_loss = 0.
            running_acc = 0.

            # Iterate over data.
            for inputs, labels in dataloader:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                # forward and backward
                with torch.set_grad_enabled(phase == 'train'):
                    preds = model(inputs)
                    loss_value = loss(preds, labels)
                    preds_class = preds.argmax(dim=1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss_value.backward()
                        optimizer.step()
                        scheduler.step()

                # statistics
                running_loss += loss_value.item()
                running_acc += (preds_class == labels.data).float().mean()

            epoch_loss = running_loss / len(dataloader)
            epoch_acc = running_acc / len(dataloader)
            
            if phase == 'train':
                train_loss_history.append(epoch_loss)
                train_accuracy_history.append(epoch_acc)
            else:
                valid_loss_history.append(epoch_loss)
                valid_accuracy_history.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc), flush=True)

    return model, train_loss_history, valid_loss_history, train_accuracy_history, valid_accuracy_history

# %%
model, train_loss_history, valid_loss_history, train_accuracy_history, valid_accuracy_history = train_model(
    model, loss, optimizer, scheduler, num_epochs=EPOCHS
);
# Out:
# Epoch 0/199:
# train Loss: 1.0376 Acc: 0.4375
# val Loss: 0.7859 Acc: 0.6250
# Epoch 1/199:
# train Loss: 0.7326 Acc: 0.5938
# val Loss: 0.8580 Acc: 0.5000
# Epoch 2/199:
# train Loss: 0.5618 Acc: 0.7500
# val Loss: 0.9154 Acc: 0.5000
# Epoch 3/199:
# train Loss: 0.3860 Acc: 0.7812
# val Loss: 0.9590 Acc: 0.5000
# Epoch 4/199:
# train Loss: 0.4804 Acc: 0.7812
# val Loss: 0.9128 Acc: 0.5000
# Epoch 5/199:
# train Loss: 0.3918 Acc: 0.8125
# val Loss: 0.8979 Acc: 0.5000
# Epoch 6/199:
# train Loss: 0.4085 Acc: 0.8125
# val Loss: 0.8999 Acc: 0.5000
# Epoch 7/199:
# train Loss: 0.3720 Acc: 0.8750
# val Loss: 0.8790 Acc: 0.5000
# Epoch 8/199:
# train Loss: 0.3475 Acc: 0.9062
# val Loss: 0.8761 Acc: 0.3750
# Epoch 9/199:
# train Loss: 0.5545 Acc: 0.7188
# val Loss: 0.8555 Acc: 0.3750
# Epoch 10/199:
# train Loss: 0.3589 Acc: 0.8438
# val Loss: 0.8543 Acc: 0.3750
# Epoch 11/199:
# train Loss: 0.3367 Acc: 0.8750
# val Loss: 0.8470 Acc: 0.3750
# Epoch 12/199:
# train Loss: 0.3992 Acc: 0.8125
# val Loss: 0.8434 Acc: 0.3750
# Epoch 13/199:
# train Loss: 0.3602 Acc: 0.9062
# val Loss: 0.8452 Acc: 0.3750
# Epoch 14/199:
# train Loss: 0.4016 Acc: 0.8438
# val Loss: 0.8548 Acc: 0.5000
# Epoch 15/199:
# train Loss: 0.3476 Acc: 0.8438
# val Loss: 0.8729 Acc: 0.3750
# Epoch 16/199:
# train Loss: 0.3472 Acc: 0.9062
# val Loss: 0.8780 Acc: 0.3750
# Epoch 17/199:
# train Loss: 0.3453 Acc: 0.8438
# val Loss: 0.8708 Acc: 0.3750
# Epoch 18/199:
# train Loss: 0.4833 Acc: 0.7812
# val Loss: 0.8790 Acc: 0.5000
# Epoch 19/199:
# train Loss: 0.3975 Acc: 0.8125
# val Loss: 0.8827 Acc: 0.5000
# Epoch 20/199:
# train Loss: 0.4201 Acc: 0.7812
# val Loss: 0.8848 Acc: 0.5000
# Epoch 21/199:
# train Loss: 0.3808 Acc: 0.8125
# val Loss: 0.8541 Acc: 0.3750
# Epoch 22/199:
# train Loss: 0.3554 Acc: 0.8125
# val Loss: 0.8616 Acc: 0.5000
# Epoch 23/199:
# train Loss: 0.4016 Acc: 0.8750
# val Loss: 0.8694 Acc: 0.5000
# Epoch 24/199:
# train Loss: 0.3595 Acc: 0.8750
# val Loss: 0.8576 Acc: 0.3750
# Epoch 25/199:
# train Loss: 0.4164 Acc: 0.8438
# val Loss: 0.8687 Acc: 0.3750
# Epoch 26/199:
# train Loss: 0.5010 Acc: 0.7812
# val Loss: 0.8469 Acc: 0.3750
# Epoch 27/199:
# train Loss: 0.3642 Acc: 0.8125
# val Loss: 0.8316 Acc: 0.3750
# Epoch 28/199:
# train Loss: 0.4099 Acc: 0.7812
# val Loss: 0.8292 Acc: 0.3750
# Epoch 29/199:
# train Loss: 0.3117 Acc: 0.8750
# val Loss: 0.8307 Acc: 0.5000
# Epoch 30/199:
# train Loss: 0.3532 Acc: 0.8750
# val Loss: 0.8395 Acc: 0.5000
# Epoch 31/199:
# train Loss: 0.4085 Acc: 0.7812
# val Loss: 0.8478 Acc: 0.3750
# Epoch 32/199:
# train Loss: 0.3106 Acc: 0.9062
# val Loss: 0.8472 Acc: 0.3750
# Epoch 33/199:
# train Loss: 0.4320 Acc: 0.7500
# val Loss: 0.8401 Acc: 0.3750
# Epoch 34/199:
# train Loss: 0.3582 Acc: 0.8438
# val Loss: 0.8541 Acc: 0.3750
# Epoch 35/199:
# train Loss: 0.3488 Acc: 0.7812
# val Loss: 0.8730 Acc: 0.5000
# Epoch 36/199:
# train Loss: 0.3287 Acc: 0.7812
# val Loss: 0.8913 Acc: 0.5000
# Epoch 37/199:
# train Loss: 0.4700 Acc: 0.7500
# val Loss: 0.9122 Acc: 0.5000
# Epoch 38/199:
# train Loss: 0.3503 Acc: 0.7812
# val Loss: 0.8918 Acc: 0.5000
# Epoch 39/199:
# train Loss: 0.3147 Acc: 0.8125
# val Loss: 0.8728 Acc: 0.5000
# Epoch 40/199:
# train Loss: 0.3474 Acc: 0.8438
# val Loss: 0.8824 Acc: 0.3750
# Epoch 41/199:
# train Loss: 0.3993 Acc: 0.8125
# val Loss: 0.8734 Acc: 0.5000
# Epoch 42/199:
# train Loss: 0.3293 Acc: 0.8125
# val Loss: 0.8586 Acc: 0.5000
# Epoch 43/199:
# train Loss: 0.3366 Acc: 0.8125
# val Loss: 0.8722 Acc: 0.5000
# Epoch 44/199:
# train Loss: 0.3404 Acc: 0.9062
# val Loss: 0.8552 Acc: 0.3750
# Epoch 45/199:
# train Loss: 0.4784 Acc: 0.8125
# val Loss: 0.8487 Acc: 0.3750
# Epoch 46/199:
# train Loss: 0.4571 Acc: 0.8438
# val Loss: 0.8723 Acc: 0.3750
# Epoch 47/199:
# train Loss: 0.3654 Acc: 0.8750
# val Loss: 0.8781 Acc: 0.3750
# Epoch 48/199:
# train Loss: 0.3827 Acc: 0.8438
# val Loss: 0.8568 Acc: 0.5000
# Epoch 49/199:
# train Loss: 0.3795 Acc: 0.8750
# val Loss: 0.8530 Acc: 0.3750
# Epoch 50/199:
# train Loss: 0.4832 Acc: 0.8125
# val Loss: 0.8594 Acc: 0.3750
# Epoch 51/199:
# train Loss: 0.3503 Acc: 0.7812
# val Loss: 0.8688 Acc: 0.3750
# Epoch 52/199:
# train Loss: 0.4450 Acc: 0.7812
# val Loss: 0.8757 Acc: 0.3750
# Epoch 53/199:
# train Loss: 0.3838 Acc: 0.8438
# val Loss: 0.8723 Acc: 0.3750
# Epoch 54/199:
# train Loss: 0.3433 Acc: 0.8438
# val Loss: 0.8507 Acc: 0.3750
# Epoch 55/199:
# train Loss: 0.2978 Acc: 0.8750
# val Loss: 0.8426 Acc: 0.3750
# Epoch 56/199:
# train Loss: 0.4251 Acc: 0.7812
# val Loss: 0.8346 Acc: 0.3750
# Epoch 57/199:
# train Loss: 0.3880 Acc: 0.8125
# val Loss: 0.8459 Acc: 0.3750
# Epoch 58/199:
# train Loss: 0.3958 Acc: 0.8438
# val Loss: 0.8366 Acc: 0.3750
# Epoch 59/199:
# train Loss: 0.3987 Acc: 0.7500
# val Loss: 0.8381 Acc: 0.3750
# Epoch 60/199:
# train Loss: 0.4440 Acc: 0.8438
# val Loss: 0.8317 Acc: 0.3750
# Epoch 61/199:
# train Loss: 0.5271 Acc: 0.7188
# val Loss: 0.8246 Acc: 0.3750
# Epoch 62/199:
# train Loss: 0.3832 Acc: 0.8438
# val Loss: 0.8307 Acc: 0.3750
# Epoch 63/199:
# train Loss: 0.3377 Acc: 0.8438
# val Loss: 0.8684 Acc: 0.3750
# Epoch 64/199:
# train Loss: 0.3585 Acc: 0.8750
# val Loss: 0.8558 Acc: 0.5000
# Epoch 65/199:
# train Loss: 0.3843 Acc: 0.8750
# val Loss: 0.8299 Acc: 0.3750
# Epoch 66/199:
# train Loss: 0.4088 Acc: 0.8438
# val Loss: 0.8381 Acc: 0.3750
# Epoch 67/199:
# train Loss: 0.3378 Acc: 0.8125
# val Loss: 0.8392 Acc: 0.3750
# Epoch 68/199:
# train Loss: 0.4323 Acc: 0.8125
# val Loss: 0.8454 Acc: 0.3750
# Epoch 69/199:
# train Loss: 0.3429 Acc: 0.8125
# val Loss: 0.8470 Acc: 0.3750
# Epoch 70/199:
# train Loss: 0.3612 Acc: 0.8125
# val Loss: 0.8543 Acc: 0.3750
# Epoch 71/199:
# train Loss: 0.3711 Acc: 0.8750
# val Loss: 0.8468 Acc: 0.3750
# Epoch 72/199:
# train Loss: 0.3393 Acc: 0.8125
# val Loss: 0.8643 Acc: 0.3750
# Epoch 73/199:
# train Loss: 0.3282 Acc: 0.8438
# val Loss: 0.8652 Acc: 0.3750
# Epoch 74/199:
# train Loss: 0.4028 Acc: 0.7812
# val Loss: 0.8754 Acc: 0.5000
# Epoch 75/199:
# train Loss: 0.4150 Acc: 0.7812
# val Loss: 0.8613 Acc: 0.5000
# Epoch 76/199:
# train Loss: 0.3212 Acc: 0.9062
# val Loss: 0.8739 Acc: 0.5000
# Epoch 77/199:
# train Loss: 0.3677 Acc: 0.8125
# val Loss: 0.8750 Acc: 0.5000
# Epoch 78/199:
# train Loss: 0.4390 Acc: 0.7188
# val Loss: 0.8745 Acc: 0.3750
# Epoch 79/199:
# train Loss: 0.4654 Acc: 0.7812
# val Loss: 0.8607 Acc: 0.3750
# Epoch 80/199:
# train Loss: 0.3611 Acc: 0.8125
# val Loss: 0.8659 Acc: 0.3750
# Epoch 81/199:
# train Loss: 0.4241 Acc: 0.7812
# val Loss: 0.8612 Acc: 0.3750
# Epoch 82/199:
# train Loss: 0.4294 Acc: 0.8438
# val Loss: 0.8706 Acc: 0.5000
# Epoch 83/199:
# train Loss: 0.5212 Acc: 0.7188
# val Loss: 0.8675 Acc: 0.3750
# Epoch 84/199:
# train Loss: 0.3622 Acc: 0.8125
# val Loss: 0.8573 Acc: 0.3750
# Epoch 85/199:
# train Loss: 0.3116 Acc: 0.9062
# val Loss: 0.8467 Acc: 0.3750
# Epoch 86/199:
# train Loss: 0.3645 Acc: 0.8750
# val Loss: 0.8334 Acc: 0.3750
# Epoch 87/199:
# train Loss: 0.4276 Acc: 0.8438
# val Loss: 0.8457 Acc: 0.3750
# Epoch 88/199:
# train Loss: 0.3753 Acc: 0.8438
# val Loss: 0.8440 Acc: 0.3750
# Epoch 89/199:
# train Loss: 0.3061 Acc: 0.8750
# val Loss: 0.8439 Acc: 0.5000
# Epoch 90/199:
# train Loss: 0.3453 Acc: 0.8438
# val Loss: 0.8389 Acc: 0.3750
# Epoch 91/199:
# train Loss: 0.4840 Acc: 0.7812
# val Loss: 0.8470 Acc: 0.5000
# Epoch 92/199:
# train Loss: 0.3353 Acc: 0.8438
# val Loss: 0.8481 Acc: 0.5000
# Epoch 93/199:
# train Loss: 0.3628 Acc: 0.9062
# val Loss: 0.8676 Acc: 0.3750
# Epoch 94/199:
# train Loss: 0.3856 Acc: 0.8125
# val Loss: 0.8615 Acc: 0.3750
# Epoch 95/199:
# train Loss: 0.3389 Acc: 0.8438
# val Loss: 0.8727 Acc: 0.3750
# Epoch 96/199:
# train Loss: 0.3543 Acc: 0.8438
# val Loss: 0.8847 Acc: 0.5000
# Epoch 97/199:
# train Loss: 0.3591 Acc: 0.9062
# val Loss: 0.8752 Acc: 0.5000
# Epoch 98/199:
# train Loss: 0.3190 Acc: 0.8750
# val Loss: 0.8681 Acc: 0.5000
# Epoch 99/199:
# train Loss: 0.3769 Acc: 0.8438
# val Loss: 0.8511 Acc: 0.5000
# Epoch 100/199:
# train Loss: 0.3875 Acc: 0.8750
# val Loss: 0.8321 Acc: 0.3750
# Epoch 101/199:
# train Loss: 0.3522 Acc: 0.8125
# val Loss: 0.8375 Acc: 0.3750
# Epoch 102/199:
# train Loss: 0.3278 Acc: 0.8438
# val Loss: 0.8558 Acc: 0.5000
# Epoch 103/199:
# train Loss: 0.3492 Acc: 0.8438
# val Loss: 0.8454 Acc: 0.3750
# Epoch 104/199:
# train Loss: 0.3210 Acc: 0.9062
# val Loss: 0.8409 Acc: 0.3750
# Epoch 105/199:
# train Loss: 0.3595 Acc: 0.7812
# val Loss: 0.8478 Acc: 0.3750
# Epoch 106/199:
# train Loss: 0.3244 Acc: 0.8750
# val Loss: 0.8620 Acc: 0.5000
# Epoch 107/199:
# train Loss: 0.5156 Acc: 0.8125
# val Loss: 0.8577 Acc: 0.3750
# Epoch 108/199:
# train Loss: 0.3293 Acc: 0.9062
# val Loss: 0.8615 Acc: 0.3750
# Epoch 109/199:
# train Loss: 0.3695 Acc: 0.8438
# val Loss: 0.8707 Acc: 0.3750
# Epoch 110/199:
# train Loss: 0.3465 Acc: 0.8438
# val Loss: 0.8586 Acc: 0.3750
# Epoch 111/199:
# train Loss: 0.4467 Acc: 0.7500
# val Loss: 0.9038 Acc: 0.3750
# Epoch 112/199:
# train Loss: 0.3759 Acc: 0.8125
# val Loss: 0.8871 Acc: 0.3750
# Epoch 113/199:
# train Loss: 0.3181 Acc: 0.9062
# val Loss: 0.8911 Acc: 0.3750
# Epoch 114/199:
# train Loss: 0.4161 Acc: 0.8438
# val Loss: 0.8870 Acc: 0.3750
# Epoch 115/199:
# train Loss: 0.3819 Acc: 0.7812
# val Loss: 0.8700 Acc: 0.5000
# Epoch 116/199:
# train Loss: 0.3448 Acc: 0.8438
# val Loss: 0.8506 Acc: 0.5000
# Epoch 117/199:
# train Loss: 0.3643 Acc: 0.8438
# val Loss: 0.8643 Acc: 0.5000
# Epoch 118/199:
# train Loss: 0.3751 Acc: 0.8125
# val Loss: 0.8652 Acc: 0.5000
# Epoch 119/199:
# train Loss: 0.3348 Acc: 0.8750
# val Loss: 0.8716 Acc: 0.5000
# Epoch 120/199:
# train Loss: 0.3293 Acc: 0.9062
# val Loss: 0.8711 Acc: 0.5000
# Epoch 121/199:
# train Loss: 0.4496 Acc: 0.8125
# val Loss: 0.8573 Acc: 0.3750
# Epoch 122/199:
# train Loss: 0.2985 Acc: 0.8438
# val Loss: 0.8635 Acc: 0.3750
# Epoch 123/199:
# train Loss: 0.4159 Acc: 0.8438
# val Loss: 0.8637 Acc: 0.3750
# Epoch 124/199:
# train Loss: 0.3882 Acc: 0.8750
# val Loss: 0.8607 Acc: 0.3750
# Epoch 125/199:
# train Loss: 0.3886 Acc: 0.7812
# val Loss: 0.8533 Acc: 0.3750
# Epoch 126/199:
# train Loss: 0.3761 Acc: 0.8125
# val Loss: 0.8460 Acc: 0.3750
# Epoch 127/199:
# train Loss: 0.3440 Acc: 0.9375
# val Loss: 0.8406 Acc: 0.3750
# Epoch 128/199:
# train Loss: 0.4237 Acc: 0.7812
# val Loss: 0.8476 Acc: 0.3750
# Epoch 129/199:
# train Loss: 0.4181 Acc: 0.7500
# val Loss: 0.8400 Acc: 0.3750
# Epoch 130/199:
# train Loss: 0.5041 Acc: 0.8125
# val Loss: 0.8715 Acc: 0.3750
# Epoch 131/199:
# train Loss: 0.3831 Acc: 0.8125
# val Loss: 0.8524 Acc: 0.5000
# Epoch 132/199:
# train Loss: 0.3908 Acc: 0.8438
# val Loss: 0.8336 Acc: 0.3750
# Epoch 133/199:
# train Loss: 0.3414 Acc: 0.8125
# val Loss: 0.8416 Acc: 0.3750
# Epoch 134/199:
# train Loss: 0.4790 Acc: 0.7812
# val Loss: 0.8401 Acc: 0.3750
# Epoch 135/199:
# train Loss: 0.3139 Acc: 0.9062
# val Loss: 0.8509 Acc: 0.3750
# Epoch 136/199:
# train Loss: 0.3467 Acc: 0.8438
# val Loss: 0.8507 Acc: 0.3750
# Epoch 137/199:
# train Loss: 0.3308 Acc: 0.8438
# val Loss: 0.8589 Acc: 0.3750
# Epoch 138/199:
# train Loss: 0.4807 Acc: 0.7188
# val Loss: 0.8617 Acc: 0.3750
# Epoch 139/199:
# train Loss: 0.3495 Acc: 0.9062
# val Loss: 0.8616 Acc: 0.3750
# Epoch 140/199:
# train Loss: 0.3415 Acc: 0.7812
# val Loss: 0.8526 Acc: 0.3750
# Epoch 141/199:
# train Loss: 0.3571 Acc: 0.8438
# val Loss: 0.8707 Acc: 0.3750
# Epoch 142/199:
# train Loss: 0.3522 Acc: 0.8438
# val Loss: 0.8680 Acc: 0.3750
# Epoch 143/199:
# train Loss: 0.3415 Acc: 0.8438
# val Loss: 0.8620 Acc: 0.5000
# Epoch 144/199:
# train Loss: 0.3975 Acc: 0.8438
# val Loss: 0.8451 Acc: 0.5000
# Epoch 145/199:
# train Loss: 0.3716 Acc: 0.8438
# val Loss: 0.8727 Acc: 0.5000
# Epoch 146/199:
# train Loss: 0.3633 Acc: 0.8438
# val Loss: 0.8601 Acc: 0.3750
# Epoch 147/199:
# train Loss: 0.3787 Acc: 0.8125
# val Loss: 0.8483 Acc: 0.3750
# Epoch 148/199:
# train Loss: 0.3721 Acc: 0.8125
# val Loss: 0.8460 Acc: 0.3750
# Epoch 149/199:
# train Loss: 0.3596 Acc: 0.8438
# val Loss: 0.8476 Acc: 0.3750
# Epoch 150/199:
# train Loss: 0.3040 Acc: 0.8750
# val Loss: 0.8525 Acc: 0.3750
# Epoch 151/199:
# train Loss: 0.4200 Acc: 0.7812
# val Loss: 0.8464 Acc: 0.3750
# Epoch 152/199:
# train Loss: 0.3284 Acc: 0.8438
# val Loss: 0.8322 Acc: 0.3750
# Epoch 153/199:
# train Loss: 0.3483 Acc: 0.8750
# val Loss: 0.8384 Acc: 0.3750
# Epoch 154/199:
# train Loss: 0.3859 Acc: 0.8438
# val Loss: 0.8419 Acc: 0.3750
# Epoch 155/199:
# train Loss: 0.3212 Acc: 0.8125
# val Loss: 0.8651 Acc: 0.3750
# Epoch 156/199:
# train Loss: 0.3162 Acc: 0.8750
# val Loss: 0.8636 Acc: 0.3750
# Epoch 157/199:
# train Loss: 0.4145 Acc: 0.8125
# val Loss: 0.8419 Acc: 0.3750
# Epoch 158/199:
# train Loss: 0.3317 Acc: 0.8750
# val Loss: 0.8538 Acc: 0.3750
# Epoch 159/199:
# train Loss: 0.3389 Acc: 0.8438
# val Loss: 0.8741 Acc: 0.3750
# Epoch 160/199:
# train Loss: 0.4211 Acc: 0.7812
# val Loss: 0.8604 Acc: 0.3750
# Epoch 161/199:
# train Loss: 0.4231 Acc: 0.8125
# val Loss: 0.8666 Acc: 0.5000
# Epoch 162/199:
# train Loss: 0.3380 Acc: 0.8750
# val Loss: 0.8677 Acc: 0.3750
# Epoch 163/199:
# train Loss: 0.4734 Acc: 0.7812
# val Loss: 0.8746 Acc: 0.3750
# Epoch 164/199:
# train Loss: 0.3895 Acc: 0.8750
# val Loss: 0.8403 Acc: 0.3750
# Epoch 165/199:
# train Loss: 0.4358 Acc: 0.7812
# val Loss: 0.8669 Acc: 0.3750
# Epoch 166/199:
# train Loss: 0.3844 Acc: 0.8438
# val Loss: 0.8469 Acc: 0.3750
# Epoch 167/199:
# train Loss: 0.5198 Acc: 0.7188
# val Loss: 0.8573 Acc: 0.5000
# Epoch 168/199:
# train Loss: 0.3998 Acc: 0.8125
# val Loss: 0.8673 Acc: 0.3750
# Epoch 169/199:
# train Loss: 0.4134 Acc: 0.7812
# val Loss: 0.8733 Acc: 0.3750
# Epoch 170/199:
# train Loss: 0.3671 Acc: 0.8438
# val Loss: 0.8542 Acc: 0.3750
# Epoch 171/199:
# train Loss: 0.4344 Acc: 0.7812
# val Loss: 0.8552 Acc: 0.3750
# Epoch 172/199:
# train Loss: 0.3675 Acc: 0.8438
# val Loss: 0.8446 Acc: 0.3750
# Epoch 173/199:
# train Loss: 0.3970 Acc: 0.8125
# val Loss: 0.8642 Acc: 0.5000
# Epoch 174/199:
# train Loss: 0.4178 Acc: 0.8438
# val Loss: 0.8745 Acc: 0.3750
# Epoch 175/199:
# train Loss: 0.3453 Acc: 0.8750
# val Loss: 0.8617 Acc: 0.3750
# Epoch 176/199:
# train Loss: 0.4921 Acc: 0.6875
# val Loss: 0.8713 Acc: 0.5000
# Epoch 177/199:
# train Loss: 0.4414 Acc: 0.7812
# val Loss: 0.8682 Acc: 0.5000
# Epoch 178/199:
# train Loss: 0.4013 Acc: 0.8438
# val Loss: 0.8636 Acc: 0.5000
# Epoch 179/199:
# train Loss: 0.3691 Acc: 0.8125
# val Loss: 0.8708 Acc: 0.5000
# Epoch 180/199:
# train Loss: 0.3628 Acc: 0.8438
# val Loss: 0.8860 Acc: 0.3750
# Epoch 181/199:
# train Loss: 0.4040 Acc: 0.7500
# val Loss: 0.8872 Acc: 0.3750
# Epoch 182/199:
# train Loss: 0.3601 Acc: 0.8438
# val Loss: 0.8773 Acc: 0.3750
# Epoch 183/199:
# train Loss: 0.3281 Acc: 0.8438
# val Loss: 0.8862 Acc: 0.3750
# Epoch 184/199:
# train Loss: 0.2817 Acc: 0.9062
# val Loss: 0.8744 Acc: 0.3750
# Epoch 185/199:
# train Loss: 0.3103 Acc: 0.8750
# val Loss: 0.8527 Acc: 0.3750
# Epoch 186/199:
# train Loss: 0.4042 Acc: 0.8438
# val Loss: 0.8396 Acc: 0.3750
# Epoch 187/199:
# train Loss: 0.5216 Acc: 0.8125
# val Loss: 0.8582 Acc: 0.3750
# Epoch 188/199:
# train Loss: 0.3123 Acc: 0.8438
# val Loss: 0.8545 Acc: 0.3750
# Epoch 189/199:
# train Loss: 0.4213 Acc: 0.8125
# val Loss: 0.8445 Acc: 0.5000
# Epoch 190/199:
# train Loss: 0.3707 Acc: 0.8125
# val Loss: 0.8514 Acc: 0.5000
# Epoch 191/199:
# train Loss: 0.3292 Acc: 0.8438
# val Loss: 0.8625 Acc: 0.5000
# Epoch 192/199:
# train Loss: 0.4040 Acc: 0.8125
# val Loss: 0.8512 Acc: 0.5000
# Epoch 193/199:
# train Loss: 0.3673 Acc: 0.8438
# val Loss: 0.8665 Acc: 0.3750
# Epoch 194/199:
# train Loss: 0.2673 Acc: 0.9062
# val Loss: 0.8721 Acc: 0.3750
# Epoch 195/199:
# train Loss: 0.4107 Acc: 0.7812
# val Loss: 0.8786 Acc: 0.3750
# Epoch 196/199:
# train Loss: 0.3208 Acc: 0.8750
# val Loss: 0.8790 Acc: 0.3750
# Epoch 197/199:
# train Loss: 0.4424 Acc: 0.7500
# val Loss: 0.8754 Acc: 0.3750
# Epoch 198/199:
# train Loss: 0.3864 Acc: 0.7500
# val Loss: 0.8607 Acc: 0.3750
# Epoch 199/199:
# train Loss: 0.3805 Acc: 0.8125
# val Loss: 0.8604 Acc: 0.3750

# %%
dict_data  = {
    'Loss Function Train' : train_loss_history,
    'Loss Function Valid' : valid_loss_history,
    'Accuracy Train' : train_accuracy_history,
    'Accuracy Valid' : valid_accuracy_history
}

# %%
df_results = pd.DataFrame.from_dict(dict_data)

# %%
def loss_plot(data):
    
    loss_names = data.columns[:2]
    accuracy_names = data.columns[2:]
    legend_names = ['Train', 'Valid']
    
    fig, ax = plt.subplots(1, 2, figsize=(20, 8))
    
    for i, j, k in zip(loss_names, accuracy_names, legend_names):
        
        ax[0].plot(data[i].values, label=k)
        ax[1].plot(data[j].values, label=k)
        
    for i, j in enumerate(['Loss', 'Accuracy']):

        ax[i].set_title(f'{j} Loss Plot', fontsize=14)
        ax[i].set_xlabel('Epoch', fontsize=12)
        ax[i].set_ylabel(f'{j} Loss Function Value', fontsize=12)
        ax[i].legend()
        
    fig.suptitle('Result of Model Training', fontsize=18)
    plt.show()

# %% [markdown]
# Посмотрим, как изменялся loss и accuracy нашей модели.

# %%
loss_plot(df_results)

# %% [markdown]
# ## Предсказание модели

# %%
test_dir = 'test'
shutil.copytree(os.path.join(data_root, 'test'), os.path.join(test_dir, 'unknown'))
# Out:
# 'test/unknown'

# %%
class ImageFolderWithPaths(torchvision.datasets.ImageFolder):
    def __getitem__(self, index):
        original_tuple = super(ImageFolderWithPaths, self).__getitem__(index)
        path = self.imgs[index][0]
        tuple_with_path = (original_tuple + (path,))
        return tuple_with_path
    
test_dataset = ImageFolderWithPaths('/kaggle/working/test', val_transforms)

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

# %%
test_dataset
# Out:
# Dataset ImageFolderWithPaths
#     Number of datapoints: 744
#     Root location: /kaggle/working/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# Делаем предсказание.

# %%
model.eval()

test_predictions = []
test_img_paths = []
for inputs, labels, paths in tqdm(test_dataloader):
    inputs = inputs.to(device)
    labels = labels.to(device)
    with torch.set_grad_enabled(False):
        preds = model(inputs)
    test_predictions.append(
        torch.nn.functional.softmax(preds, dim=1)[:,1].data.cpu().numpy())
    test_img_paths.extend(paths)
    
test_predictions = np.concatenate(test_predictions)
# Out:
# 100%|██████████| 93/93 [00:03<00:00, 28.04it/s]

# %% [markdown]
# Далее создадим `.csv` наших предсказаний.

# %%
submission_df = pd.DataFrame.from_dict({'id': test_img_paths, 'label': test_predictions})

submission_df['label'] = submission_df['label'].map(lambda pred: 'dirty' if pred > 0.25 else 'cleaned')
submission_df['id'] = submission_df['id'].str.replace('/kaggle/working/test/unknown/', '')
submission_df['id'] = submission_df['id'].str.replace('.jpg', '')
submission_df.set_index('id', inplace=True)
submission_df.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
#       label
# id
# 0000  dirty
# 0001  dirty
# 0002  dirty
# 0003  dirty
# 0004  dirty

# %% [markdown]
# Скачиваем файлы.

# %%
submission_df.to_csv('submission.csv')

from IPython.display import FileLink
FileLink('submission.csv')
# Out:
# /kaggle/working/submission.csv

# %% [markdown]
# Очищаем рабочую папку.

# %%
# !rm -rf train val test
